# %% [markdown]
# #                                  ******PANDAS
#
# ##What is Pandas?
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.
#
# ##Why Use Pandas?
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
#
# Pandas can clean messy data sets, and make them readable and relevant.
#
# Relevant data is very important in data science.

# %% [markdown]
# ##Cleaning the data
# Pandas are also able to delete rows that are not relevant, or contains wrong values, like empty or NULL values. This is called cleaning the data.
# ##What is a Series?
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type.
# ##Labels
# If nothing else is specified, the values are labeled with their index number. First value has index 0, second value has index 1 etc.
#
# This label can be used to access a specified value.

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
#pd is short for pandas, a powerful Python library used for handling data.
#read_csv() is used to read CSV files into pandas.
df = pd.read_csv('data.csv')
print(df.to_string())
#df.to_string() forces it to print all rows and all columns, no matter how big it is.

# %%
#With the index argument, you can name your own labels.
n = pd.Series([1,2,3,4,5],index=["a","b","c","d","e"],name= "Numbers")
n
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: Numbers, dtype: int64

# %%
n["a":"d"] # last value its take because in this external index we taken
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: Numbers, dtype: int64

# %%
m= pd.Series([55,95,42,75,62],name="marks")
m
# Out:
# 0    55
# 1    95
# 2    42
# 3    75
# 4    62
# Name: marks, dtype: int64

# %%
m[0:4]    # last value is excluded
# Out:
# 0    55
# 1    95
# 2    42
# 3    75
# Name: marks, dtype: int64

# %% [markdown]
# #Key/Value Objects as Series
# You can also use a key/value object, like a dictionary, when creating a Series.
#
# #DataFrames
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
#
# Series is like a column, a DataFrame is the whole table
#
# #What is a DataFrame?
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
# #Note:
# When using `[]`, the result is a Pandas DataFrame.

# %%
lists = (["books",50],["knife",70],["paper",90])
df=pd.DataFrame(lists,columns=["item","price"])

# %%
df
# Out:
#     item  price
# 0  books     50
# 1  knife     70
# 2  paper     90

# %%
dic = pd.DataFrame({"item":["books","knife","paper"],"price":[50,70,90]})
dic
# Out:
#     item  price
# 0  books     50
# 1  knife     70
# 2  paper     90

# %% [markdown]
# #Locate Row
# As you can see from the result above, the DataFrame is like a table with rows and columns.
#
# Pandas use the loc attribute to return one or more specified row(s)

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
print('---------------------')
print(df.loc[0])
print('---------------------')
print(df.loc[[0, 1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# ---------------------
# calories    420
# duration     50
# Name: 0, dtype: int64
# ---------------------
#    calories  duration
# 0       420        50
# 1       380        40

# %% [markdown]
# #Named Indexes
# With the index argument, you can name your own indexes.

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# #Load Files Into a DataFrame
# If your data sets are stored in a file, Pandas can load them into a DataFrame.

# %%
import pandas as pd

df = pd.read_csv('/content/Smartphones_cleaned_dataset.csv')

df
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %% [markdown]
# #max_rows
# `pd.options.display.max_rows`
#
# By default,Pandas will show up to 60 rows of a DataFrame when printed.
#
# if you give`pd.options.display.max_rows = 9999 `or any value it will show upto that value.

# %% [markdown]
# # JSON
# JSON is a way to store and share data in a format that’s easy to read and write.
#
# It looks like Python dictionaries, but it’s used to exchange data between systems (like websites, APIs, files).
#
# #JSON = Python Dictionary
#
# JSON objects have the same format as Python dictionaries.

# %%
# Load a Python Dictionary into a DataFrame:

import pandas as pd

data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# #Pandas - Analyzing DataFrames
# ##✅ View the Data
#
#     df.head()              # Show first 5 rows
#     df.tail()              # Show last 5 rows
#     df.sample(5)           # Show 5 random rows
#     df.shape               # Show (rows, columns)
#     df.columns             # Show column names
#
# ##✅ Data Info
#
#     df.info()              # Show column types & non-null values
#     df.dtypes              # Data type of each column
#
# ##✅ Summary Statistics
#     df.describe()                   # Summary stats for numeric columns
#     df.describe(include='all')     # Include all column types
# ##✅ Missing & Duplicate Data
#
#     df.isnull().sum()       # Count missing values per column
#     df.notnull().sum()      # Count non-missing values
#     df.duplicated().sum()   # Count duplicate rows
#     df.drop_duplicates()    # Drop duplicates (not saved unless assigned)
# ##✅ Value Counts & Uniques
#
#     df['Column'].unique()        # List unique values
#     df['Column'].value_counts()  # Frequency of each value
# ##✅ Filter Rows
#
#     df[df['Age'] > 30]              # Rows with Age > 30
#     df[df['Gender'] == 'Male']      # Rows where Gender is Male
#     df[df['Salary'].isnull()]       # Rows with missing Salary
#
# ##✅ Sorting
#
#     df.sort_values(by='Salary')                  # Sort by Salary ascending
#     df.sort_values(by='Salary', ascending=False) # Sort by Salary descending
# ##✅ Grouping & Aggregation
#
#     df.groupby('Department').mean()           # Mean values per Department
#     df.groupby('Gender')['Salary'].sum()      # Total Salary per Gender
# ##✅ Correlation
#
#     df.corr()           # Correlation between numeric columns
# ##✅ Visualization
#
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#
#     df['Age'].hist()                        # Histogram
#     df.boxplot(column='Salary')            # Box plot
#     sns.countplot(x='Gender', data=df)     # Count by Gender
#     sns.heatmap(df.corr(), annot=True)     # Correlation heatmap
#     plt.show()                             # Show all plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df['primary_camera_rear'].hist()      # Histogram
plt.title('primary_camera_rear')
plt.show()
df.boxplot(column='price')            # Box plot
plt.title('Price')
plt.show()
sns.countplot(x='model', data=df)     # Count by model
plt.title('model')
plt.show()

# %%
# Mean = the average value (the sum of all values divided by number of values).

df = pd.read_csv('data.csv')
x = df["Calories"].mean()
df.fillna({"Calories": x}, inplace=True)

#Median = the value in the middle, after you have sorted all values ascending.

df = pd.read_csv('data.csv')
x = df["Calories"].median()
df.fillna({"Calories": x}, inplace=True)

#Mode = the value that appears most frequently.

f = pd.read_csv('data.csv')
x = df["Calories"].mode()[0]
df.fillna({"Calories": x}, inplace=True)

# %%
n.head(2)
# Out:
# a    1
# b    2
# Name: Numbers, dtype: int64

# %%
n.tail(2)
# Out:
# d    4
# e    5
# Name: Numbers, dtype: int64

# %%
n.describe()
# Out:
# count    5.000000
# mean     3.000000
# std      1.581139
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000
# Name: Numbers, dtype: float64

# %%
l = np.random.randint(1,5,size= (5,3))

# %%
l
# Out:
# array([[3, 3, 4],
#        [2, 2, 1],
#        [2, 1, 3],
#        [3, 3, 4],
#        [4, 1, 2]])

# %%
p= pd.DataFrame(l)

# %%
p
# Out:
#    0  1  2
# 0  3  3  4
# 1  2  2  1
# 2  2  1  3
# 3  3  3  4
# 4  4  1  2

# %%
series = [{'first': pd.Series([2,2,2,1.1,1]),
          'second': pd.Series([2,2,4,4,1])}]

# %%
list_of_dic = [{"a":1,"b":4,"c":6,"d":9},{"a":1,"b":4,"d":9},{"a":1,"c":6},{"a":1,"b":4,"d":9}]

# %%
df = pd.DataFrame(list_of_dic)

# %%
df
# Out:
#    a    b    c    d
# 0  1  4.0  6.0  9.0
# 1  1  4.0  NaN  9.0
# 2  1  NaN  6.0  NaN
# 3  1  4.0  NaN  9.0

# %%
list_of_dic2 = [{"a":np.nan,"b":4,"c":np.nan,"d":9},{"a":1,"b":4,"c":6,"d":9},{"a":np.nan,"b":4,"c":np.nan,"d":9},{"a":1,"b":4,"c":6,"d":9}]

# %%
pd.DataFrame(list_of_dic2)
# Out:
#      a  b    c  d
# 0  NaN  4  NaN  9
# 1  1.0  4  6.0  9
# 2  NaN  4  NaN  9
# 3  1.0  4  6.0  9

# %% [markdown]
# #🧠 Summary of Cleaning Data Tasks:
# ##🧹 Cleaning Data in Pandas:
# Cleaning data in Pandas means fixing or removing incorrect, incomplete, duplicate, or inconsistent data from your dataset so it becomes ready for analysis.
# ##Task	Method
# ##✅ 1. Handling Missing Data
#     🔸 Detect Missing Values
#       df.isnull().sum()        # Shows count of null values in each column
#       df.dropna()              # Drop rows with any NaNs
#       df.dropna(axis=1)        # Drop columns with any NaNs
#
#     🔸 Fill Missing Values
#
#       df['Age'].fillna(0)                   # Replace NaNs with 0
#       df['Gender'].fillna('Unknown')       # Fill missing strings
#       df['Score'].fillna(df['Score'].mean())  # Replace with mean
#
# ##✅ 2. Fixing Data Types
#
#       df['Date'] = pd.to_datetime(df['Date'])     # Convert to datetime
#       df['Age'] = df['Age'].astype(int)           # Convert to int
#       df['Price'] = df['Price'].astype(float)     # Convert to float
# ##✅ 3. Removing Duplicates
#
#       df.duplicated().sum()        # Count duplicates
#       df = df.drop_duplicates()    # Drop duplicate rows
# ##✅ 4. Cleaning Strings
#
#       df['Name'] = df['Name'].str.strip()        # Remove leading/trailing spaces
#       df['Name'] = df['Name'].str.title()        # Convert to Title Case
#       df['Email'] = df['Email'].str.lower()      # Convert to lowercase
# ##✅ 5. Fixing Inconsistent Data
#
#       df['Gender'].value_counts()
#     # Unify inconsistent entries
#       df['Gender'] = df['Gender'].replace({'M': 'Male', 'F': 'Female', 'male': 'Male', 'female': 'Female'})
# ##✅ 6. Handling Outliers
#
#     # Remove values beyond 3 standard deviations
#       mean = df['Score'].mean()
#       std = df['Score'].std()
#       df = df[(df['Score'] >= mean - 3*std) & (df['Score'] <= mean + 3*std)]
# ##✅ 7. Renaming Columns
#       df.rename(columns={'old_name': 'new_name'}, inplace=True)
#       df['Phone'] = df['Phone'].astype(str).apply(lambda x: x[:3] + '-' + x[3:6] + '-' + x[6:10])

# %%
import pandas as pd

df = pd.read_excel('/content/Customer Call List.xlsx')

df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
#removing the duplicate rows from the dataframe
df.drop_duplicates(inplace = True)
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
# Removing the not so usefull columns
df =  df.drop(columns=['Not_Useful_Column'])

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
# issue wiht the last_name column
df['Last_Name']
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
#removing the special chars from last name
df['Last_Name'] =  df['Last_Name'].str.strip('..._/')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
#phone number!,,---> Standard is  123-543-2345
df['Phone_Number']
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2       7066950392
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6              NaN
# 7     876|678|3469
# 8              N/a
# 9     123-545-5421
# 10             NaN
# 11      7066950392
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17      7066950392
# 18             N/a
# 19    876|678|3469
# Name: Phone_Number, dtype: object

# %%
# conver every phone no. into string
df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x)) #1
df['Phone_Number']
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2       7066950392
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6              nan
# 7     876|678|3469
# 8              N/a
# 9     123-545-5421
# 10             nan
# 11      7066950392
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17      7066950392
# 18             N/a
# 19    876|678|3469
# Name: Phone_Number, dtype: object

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace('[^a-zA-Z0-9]','',regex = True) #2
df['Phone_Number']
# Out:
# 0     1235455421
# 1     1236439775
# 2     7066950392
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6            nan
# 7     8766783469
# 8             Na
# 9     1235455421
# 10           nan
# 11    7066950392
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17    7066950392
# 18            Na
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
# to convert every phone number into standard format 123456789 -----> 123-456-6789
df['Phone_Number'] =  df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10]) #3
df['Phone_Number']
# Out:
# 0     123-545-5421
# 1     123-643-9775
# 2     706-695-0392
# 3     123-543-2345
# 4     876-678-3469
# 5     304-762-2467
# 6            nan--
# 7     876-678-3469
# 8             Na--
# 9     123-545-5421
# 10           nan--
# 11    706-695-0392
# 12    123-543-2345
# 13    876-678-3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 17    706-695-0392
# 18            Na--
# 19    876-678-3469
# Name: Phone_Number, dtype: object

# %%
#replace nan-- Na-- with nothing
df['Phone_Number'] = df['Phone_Number'].fillna('').replace({'nan--': '', 'Na--': ''})
                          # or
# df['Phone_Number'] = df['Phone_Number'].str.replace('nan--','')
# df['Phone_Number'] = df['Phone_Number'].str.replace('Na--','')
df['Phone_Number']
# Out:
# 0     123-545-5421
# 1     123-643-9775
# 2     706-695-0392
# 3     123-543-2345
# 4     876-678-3469
# 5     304-762-2467
# 6
# 7     876-678-3469
# 8
# 9     123-545-5421
# 10
# 11    706-695-0392
# 12    123-543-2345
# 13    876-678-3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 17    706-695-0392
# 18
# 19    876-678-3469
# Name: Phone_Number, dtype: object

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...

# %%
# Yes ---> Y
# No ---> N

df['Paying Customer'] = df['Paying Customer'].replace('Yes', 'Y')
# df['Paying Customer'] = df['Paying Customer'].str.replace('Yes','Y')
df['Paying Customer'] = df['Paying Customer'].replace('No', 'N')
# df['Paying Customer'] = df['Paying Customer'].str.replace('No','N')
df['Paying Customer'] = df['Paying Customer'].replace('N/a','')
# df['Paying Customer'] = df['Paying Customer'].str.replace('N/a','')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...

# %%
df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('Yes','Y')
df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('No','N')
df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('NaN','')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...
